# %%
import numpy as np
import pandas as pd

# %%
survey_data = pd.read_csv("SQLOutputCulibel.csv")

# %%
survey_data.head()
# Out:
#   Subcollectie            originalNameUsage  genus  scientificName  \
# 0     Algemeen  Aedes cinereus Meigen, 1818  Aedes  Aedes cinereus
# 1     Algemeen  Aedes cinereus Meigen, 1818  Aedes  Aedes cinereus
# 2     Algemeen  Aedes cinereus Meigen, 1818  Aedes  Aedes cinereus
# 3     Algemeen  Aedes cinereus Meigen, 1818  Aedes  Aedes cinereus
# 4     Algemeen  Aedes cinereus Meigen, 1818  Aedes  Aedes cinereus
#
#   specificEpithet   type language  \
# 0        cinereus  Event       en
# 1        cinereus  Event       en
# 2        cinereus  Event       en
# 3        cinereus  Event       en
# 4        cinereus  Event       en
#
#                                            license rightsHolder  \
# 0  https://creativecommons.org/licenses/by-nc/4.0/        RBINS
# 1  https://creativecommons.org/licenses/by-nc/4.0/        RBINS
# 2  https://creativecommons.org/licenses/by-nc/4.0/        RBINS
# 3  https://creativecommons.org/licenses/by-nc/4.0/        RBINS
# 4  https://creativecommons.org/licenses/by-nc/4.0/        RBINS
#
#                                accessRights     ...            Veld12  \
# 0  http://www.inbo.be/en/norms-for-data-use     ...       3C-5-Culi-6
# 1  http://www.inbo.be/en/norms-for-data-use     ...       3C-5-Culi-6
# 2  http://www.inbo.be/en/norms-for-data-use     ...       3C-5-Culi-6
# 3  http://www.inbo.be/en/norms-for-data-use     ...       3C-5-Culi-6
# 4  http://www.inbo.be/en/norms-for-data-use     ...       3C-5-Culi-6
#
#   catalogNumber                  occurrenceID Column       Provincie  \
# 0             1  RBINS:modirisk:collection::1    NaN   East Flanders
# 1             2  RBINS:modirisk:collection::2    NaN  Brabant Wallon
# 2             3  RBINS:modirisk:collection::3    NaN         Antwerp
# 3             4  RBINS:modirisk:collection::4    NaN   East Flanders
# 4             5  RBINS:modirisk:collection::5    NaN   East Flanders
#
#              X            Y    TAG      POINT_X      POINT_Y
# 0  111577.4424  195252.2128  ES55B  111577.4424  195252.2128
# 1  160934.7585  159322.5036  FS02D  160934.7585  159322.5036
# 2  207051.8335  218484.7379  FS58C  207051.8335  218484.7379
# 3  111577.4424  195252.2128  ES55B  111577.4424  195252.2128
# 4  111577.4424  195252.2128  ES55B  111577.4424  195252.2128
#
# [5 rows x 41 columns]

# %%
import pyproj
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-c6ec65490265> in <module>()
# ----> 1 import pyproj
#
# ModuleNotFoundError: No module named 'pyproj'

# %%
lambert = pyproj.Proj("+init=EPSG:31370")
wgs84 = pyproj.Proj("+init=EPSG:4326")

# %%
pyproj.transform(lambert, wgs84,221651,44263)
# Out:
# (5.362054552936575, 49.70567727063289)

# %%
def transform_lambert_to_wgs(row):
    """
    Converts the x and y coordinates of this row into a Series of the
    longitude and latitude.
    
    """
    return pd.Series(pyproj.transform(lambert, wgs84, row['X'], row['Y']))

# %%
transform_lambert_to_wgs(survey_data.loc[0])
# Out:
# 0     3.820617
# 1    51.066137
# dtype: float64

# %%
survey_data.apply(transform_lambert_to_wgs, axis=1)
# Out:
#              0          1
# 0     3.820617  51.066137
# 1     4.523680  50.744321
# 2     5.186295  51.273408
# 3     3.820617  51.066137
# 4     3.820617  51.066137
# 5     4.329038  51.376206
# 6     4.329038  51.376206
# 7     3.251229  51.338514
# 8     3.251229  51.338514
# 9     3.251229  51.338514
# 10    3.749266  51.066617
# 11    3.749266  51.066617
# 12    3.749266  51.066617
# 13    3.749266  51.066617
# 14    4.384642  50.835989
# 15    5.525863  49.602492
# 16    5.594991  49.600962
# 17    3.749266  51.066617
# 18    5.186295  51.273408
# 19    3.749266  51.066617
# 20    5.186295  51.273408
# 21    5.186295  51.273408
# 22    4.384642  50.835989
# 23    4.384642  50.835989
# 24    5.651487  50.634172
# 25    5.186295  51.273408
# 26    5.651487  50.634172
# 27    4.455626  50.835124
# 28    5.186295  51.273408
# 29    5.186295  51.273408
# ...        ...        ...
# 1344  5.631462  50.274821
# 1345  6.139392  50.584246
# 1346  5.981856  50.536225
# 1347  5.911785  50.268132
# 1348  4.603752  51.013049
# 1349  3.962381  51.020093
# 1350  5.432627  50.504029
# 1351  5.769031  50.226645
# 1352  5.911785  50.268132
# 1353  6.021725  50.446361
# 1354  4.362509  50.071774
# 1355  3.819823  51.021180
# 1356  4.383314  50.791038
# 1357  3.747818  50.976700
# 1358  4.538460  51.193788
# 1359  3.819823  51.021180
# 1360  3.747818  50.976700
# 1361  5.150809  50.509579
# 1362  4.362509  50.071774
# 1363  4.362509  50.071774
# 1364  3.880918  50.481150
# 1365  4.362509  50.071774
# 1366  3.962381  51.020093
# 1367  4.362509  50.071774
# 1368  3.892831  51.110571
# 1369  3.892831  51.110571
# 1370  4.362509  50.071774
# 1371  3.820617  51.066137
# 1372  4.761611  51.415464
# 1373  6.021725  50.446361
#
# [1374 rows x 2 columns]

# %%
survey_data[["decimalLongitude" ,"decimalLatitude"]] = survey_data.apply(transform_lambert_to_wgs, axis=1)

# %%
survey_data.head()
# Out:
#   Subcollectie            originalNameUsage  genus  scientificName  \
# 0     Algemeen  Aedes cinereus Meigen, 1818  Aedes  Aedes cinereus
# 1     Algemeen  Aedes cinereus Meigen, 1818  Aedes  Aedes cinereus
# 2     Algemeen  Aedes cinereus Meigen, 1818  Aedes  Aedes cinereus
# 3     Algemeen  Aedes cinereus Meigen, 1818  Aedes  Aedes cinereus
# 4     Algemeen  Aedes cinereus Meigen, 1818  Aedes  Aedes cinereus
#
#   specificEpithet   type language  \
# 0        cinereus  Event       en
# 1        cinereus  Event       en
# 2        cinereus  Event       en
# 3        cinereus  Event       en
# 4        cinereus  Event       en
#
#                                            license rightsHolder  \
# 0  https://creativecommons.org/licenses/by-nc/4.0/        RBINS
# 1  https://creativecommons.org/licenses/by-nc/4.0/        RBINS
# 2  https://creativecommons.org/licenses/by-nc/4.0/        RBINS
# 3  https://creativecommons.org/licenses/by-nc/4.0/        RBINS
# 4  https://creativecommons.org/licenses/by-nc/4.0/        RBINS
#
#                                accessRights       ...        \
# 0  http://www.inbo.be/en/norms-for-data-use       ...
# 1  http://www.inbo.be/en/norms-for-data-use       ...
# 2  http://www.inbo.be/en/norms-for-data-use       ...
# 3  http://www.inbo.be/en/norms-for-data-use       ...
# 4  http://www.inbo.be/en/norms-for-data-use       ...
#
#                    occurrenceID Column       Provincie            X  \
# 0  RBINS:modirisk:collection::1    NaN   East Flanders  111577.4424
# 1  RBINS:modirisk:collection::2    NaN  Brabant Wallon  160934.7585
# 2  RBINS:modirisk:collection::3    NaN         Antwerp  207051.8335
# 3  RBINS:modirisk:collection::4    NaN   East Flanders  111577.4424
# 4  RBINS:modirisk:collection::5    NaN   East Flanders  111577.4424
#
#              Y    TAG      POINT_X      POINT_Y decimalLongitude  \
# 0  195252.2128  ES55B  111577.4424  195252.2128         3.820617
# 1  159322.5036  FS02D  160934.7585  159322.5036         4.523680
# 2  218484.7379  FS58C  207051.8335  218484.7379         5.186295
# 3  195252.2128  ES55B  111577.4424  195252.2128         3.820617
# 4  195252.2128  ES55B  111577.4424  195252.2128         3.820617
#
#   decimalLatitude
# 0       51.066137
# 1       50.744321
# 2       51.273408
# 3       51.066137
# 4       51.066137
#
# [5 rows x 43 columns]

# %%
survey_data.to_csv("survey_data_completed.csv", index=False)

# %%
survey_data["datasetName2"] = 'Modirisk_collection_data'

# %%
survey_data.head()
# Out:
#   Subcollectie            originalNameUsage  genus  scientificName  \
# 0     Algemeen  Aedes cinereus Meigen, 1818  Aedes  Aedes cinereus
# 1     Algemeen  Aedes cinereus Meigen, 1818  Aedes  Aedes cinereus
# 2     Algemeen  Aedes cinereus Meigen, 1818  Aedes  Aedes cinereus
# 3     Algemeen  Aedes cinereus Meigen, 1818  Aedes  Aedes cinereus
# 4     Algemeen  Aedes cinereus Meigen, 1818  Aedes  Aedes cinereus
#
#   specificEpithet   type language  \
# 0        cinereus  Event       en
# 1        cinereus  Event       en
# 2        cinereus  Event       en
# 3        cinereus  Event       en
# 4        cinereus  Event       en
#
#                                            license rightsHolder  \
# 0  https://creativecommons.org/licenses/by-nc/4.0/        RBINS
# 1  https://creativecommons.org/licenses/by-nc/4.0/        RBINS
# 2  https://creativecommons.org/licenses/by-nc/4.0/        RBINS
# 3  https://creativecommons.org/licenses/by-nc/4.0/        RBINS
# 4  https://creativecommons.org/licenses/by-nc/4.0/        RBINS
#
#                                accessRights            ...             \
# 0  http://www.inbo.be/en/norms-for-data-use            ...
# 1  http://www.inbo.be/en/norms-for-data-use            ...
# 2  http://www.inbo.be/en/norms-for-data-use            ...
# 3  http://www.inbo.be/en/norms-for-data-use            ...
# 4  http://www.inbo.be/en/norms-for-data-use            ...
#
#         Provincie            X            Y    TAG      POINT_X      POINT_Y  \
# 0   East Flanders  111577.4424  195252.2128  ES55B  111577.4424  195252.2128
# 1  Brabant Wallon  160934.7585  159322.5036  FS02D  160934.7585  159322.5036
# 2         Antwerp  207051.8335  218484.7379  FS58C  207051.8335  218484.7379
# 3   East Flanders  111577.4424  195252.2128  ES55B  111577.4424  195252.2128
# 4   East Flanders  111577.4424  195252.2128  ES55B  111577.4424  195252.2128
#
#   decimalLongitude decimalLatitude   georeferenceRemarks  \
# 0         3.820617       51.066137  georeference_attempt
# 1         4.523680       50.744321  georeference_attempt
# 2         5.186295       51.273408  georeference_attempt
# 3         3.820617       51.066137  georeference_attempt
# 4         3.820617       51.066137  georeference_attempt
#
#                datasetName2
# 0  Modirisk_collection_data
# 1  Modirisk_collection_data
# 2  Modirisk_collection_data
# 3  Modirisk_collection_data
# 4  Modirisk_collection_data
#
# [5 rows x 45 columns]

# %%
survey_data["georeferenceRemarks"] = 'georeference_attempt'

# %%
survey_data.head()
# Out:
#   Subcollectie            originalNameUsage  genus  scientificName  \
# 0     Algemeen  Aedes cinereus Meigen, 1818  Aedes  Aedes cinereus
# 1     Algemeen  Aedes cinereus Meigen, 1818  Aedes  Aedes cinereus
# 2     Algemeen  Aedes cinereus Meigen, 1818  Aedes  Aedes cinereus
# 3     Algemeen  Aedes cinereus Meigen, 1818  Aedes  Aedes cinereus
# 4     Algemeen  Aedes cinereus Meigen, 1818  Aedes  Aedes cinereus
#
#   specificEpithet   type language  \
# 0        cinereus  Event       en
# 1        cinereus  Event       en
# 2        cinereus  Event       en
# 3        cinereus  Event       en
# 4        cinereus  Event       en
#
#                                            license rightsHolder  \
# 0  https://creativecommons.org/licenses/by-nc/4.0/        RBINS
# 1  https://creativecommons.org/licenses/by-nc/4.0/        RBINS
# 2  https://creativecommons.org/licenses/by-nc/4.0/        RBINS
# 3  https://creativecommons.org/licenses/by-nc/4.0/        RBINS
# 4  https://creativecommons.org/licenses/by-nc/4.0/        RBINS
#
#                                accessRights            ...             \
# 0  http://www.inbo.be/en/norms-for-data-use            ...
# 1  http://www.inbo.be/en/norms-for-data-use            ...
# 2  http://www.inbo.be/en/norms-for-data-use            ...
# 3  http://www.inbo.be/en/norms-for-data-use            ...
# 4  http://www.inbo.be/en/norms-for-data-use            ...
#
#         Provincie            X            Y    TAG      POINT_X      POINT_Y  \
# 0   East Flanders  111577.4424  195252.2128  ES55B  111577.4424  195252.2128
# 1  Brabant Wallon  160934.7585  159322.5036  FS02D  160934.7585  159322.5036
# 2         Antwerp  207051.8335  218484.7379  FS58C  207051.8335  218484.7379
# 3   East Flanders  111577.4424  195252.2128  ES55B  111577.4424  195252.2128
# 4   East Flanders  111577.4424  195252.2128  ES55B  111577.4424  195252.2128
#
#   decimalLongitude decimalLatitude   georeferenceRemarks  \
# 0         3.820617       51.066137  georeference_attempt
# 1         4.523680       50.744321  georeference_attempt
# 2         5.186295       51.273408  georeference_attempt
# 3         3.820617       51.066137  georeference_attempt
# 4         3.820617       51.066137  georeference_attempt
#
#                datasetName2
# 0  Modirisk_collection_data
# 1  Modirisk_collection_data
# 2  Modirisk_collection_data
# 3  Modirisk_collection_data
# 4  Modirisk_collection_data
#
# [5 rows x 45 columns]

# %%
survey_data.head()
# Out:
#   Subcollectie            originalNameUsage  genus  scientificName  \
# 0     Algemeen  Aedes cinereus Meigen, 1818  Aedes  Aedes cinereus
# 1     Algemeen  Aedes cinereus Meigen, 1818  Aedes  Aedes cinereus
# 2     Algemeen  Aedes cinereus Meigen, 1818  Aedes  Aedes cinereus
# 3     Algemeen  Aedes cinereus Meigen, 1818  Aedes  Aedes cinereus
# 4     Algemeen  Aedes cinereus Meigen, 1818  Aedes  Aedes cinereus
#
#   specificEpithet   type language  \
# 0        cinereus  Event       en
# 1        cinereus  Event       en
# 2        cinereus  Event       en
# 3        cinereus  Event       en
# 4        cinereus  Event       en
#
#                                            license rightsHolder  \
# 0  https://creativecommons.org/licenses/by-nc/4.0/        RBINS
# 1  https://creativecommons.org/licenses/by-nc/4.0/        RBINS
# 2  https://creativecommons.org/licenses/by-nc/4.0/        RBINS
# 3  https://creativecommons.org/licenses/by-nc/4.0/        RBINS
# 4  https://creativecommons.org/licenses/by-nc/4.0/        RBINS
#
#                                accessRights            ...             \
# 0  http://www.inbo.be/en/norms-for-data-use            ...
# 1  http://www.inbo.be/en/norms-for-data-use            ...
# 2  http://www.inbo.be/en/norms-for-data-use            ...
# 3  http://www.inbo.be/en/norms-for-data-use            ...
# 4  http://www.inbo.be/en/norms-for-data-use            ...
#
#         Provincie            X            Y    TAG      POINT_X      POINT_Y  \
# 0   East Flanders  111577.4424  195252.2128  ES55B  111577.4424  195252.2128
# 1  Brabant Wallon  160934.7585  159322.5036  FS02D  160934.7585  159322.5036
# 2         Antwerp  207051.8335  218484.7379  FS58C  207051.8335  218484.7379
# 3   East Flanders  111577.4424  195252.2128  ES55B  111577.4424  195252.2128
# 4   East Flanders  111577.4424  195252.2128  ES55B  111577.4424  195252.2128
#
#   decimalLongitude decimalLatitude   georeferenceRemarks  \
# 0         3.820617       51.066137  georeference_attempt
# 1         4.523680       50.744321  georeference_attempt
# 2         5.186295       51.273408  georeference_attempt
# 3         3.820617       51.066137  georeference_attempt
# 4         3.820617       51.066137  georeference_attempt
#
#                datasetName2
# 0  Modirisk_collection_data
# 1  Modirisk_collection_data
# 2  Modirisk_collection_data
# 3  Modirisk_collection_data
# 4  Modirisk_collection_data
#
# [5 rows x 45 columns]

# %%
survey_data.to_csv("survey_data_completed.csv", index=False)
